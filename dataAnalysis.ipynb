# %% [markdown]
# # Data analysis
#
# In this notebook, code for reproducing all the Figure of [INTEGRATE paper]() is presented.

# %%
import pandas as pd
import matplotlib.image as img
import matplotlib.pyplot as plt
pipelineDir = './pipeline'
import sys
import os
sys.path.append(pipelineDir)
import genericLib as gL

workingDirs = gL.setWorkingDirs()
OUTDIR = workingDirs[2]
FIGUREDIR = workingDirs[4]

# %% [markdown]
# # Figure 2
#
# To run the script from the Jupyter notebook:
# ```python
# !python pipeline/dataAnalysis.py
# ```
#
# In alternative, to run the script from the terminal:
# ```python
# python pipeline/dataAnalysis.py
# ```

# %%
# !python pipeline/dataAnalysis.py
# Out:
# C:\Users\Marzia\anaconda3_new\envs\integrate\lib\site-packages\anndata\_core\anndata.py:1220: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'clusters' as categorical
# C:\Users\Marzia\anaconda3_new\envs\integrate\lib\site-packages\scanpy\tools\_rank_genes_groups.py:420: RuntimeWarning: invalid value encountered in log2
#   self.stats[group_name, 'logfoldchanges'] = np.log2(

# %% [markdown]
# The produced outputs are:
# 1. Cell Vs Protein figure

# %%
im = img.imread(os.path.join(FIGUREDIR, 'ProteinsVsCells.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# 2. Cell Vs Time figure

# %%
im = img.imread(os.path.join(FIGUREDIR, 'CellsVsTime.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# 3. Proteins Vs Time figure

# %%
im = img.imread(os.path.join(FIGUREDIR, 'ProteinsVsTime.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# 4. t-SNE of metabolomic data

# %%
im = img.imread(os.path.join(FIGUREDIR, 'tsne.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# 5. Dotplot

# %%
im = img.imread(os.path.join(FIGUREDIR, 'dotplot.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# # Figure 3A
#
# Firstly t-SNE is executed on a subset of the sampled solutions from the Step 6.
# To run the script from the Jupyter notebook:
# ```python
# !python pipeline/PCAwtSNE.py tStampRS
# ```
#
# In alternative, to run the script from the terminal:
# ```python
# python pipeline/PCAwtSNE.py tStampRS
# ```
# Parameters:
# - *tStampRS* is the time stamp of the random sampling output file. For constraint 1 the time stamp is *20210412081408*, for constraint 2 is *20210412174332*, for constraint 3 is *20210423112500*, and for constraint 1+2+3 it is *20210406172233*.
#
# Because of the high dimension of the random sampling input files, this notebook don't show the execution of this phase, which is commented in the following cells to be easily executed by the user, but only the resulting output:
#
# ## Constraint 1

# %%
# !python pipeline/PCAwtSNE.py 20210412081408

# %% [markdown]
# 1. t-SNE execution:

# %%
dftsne_constraint1 = pd.read_csv(os.path.join(OUTDIR, 'tsnewPca_rs_20210412081408_extr_0.csv'), sep = '\t', index_col = 0)
dftsne_constraint1
# Out:
#        cellLine  tsne-2d-one  tsne-2d-two
# 0       MCF102A    21.718903   -12.540482
# 1       MCF102A    21.720993   -12.547372
# 2       MCF102A    33.773540    25.889065
# 3       MCF102A    41.852570    29.698450
# 4       MCF102A    40.864790   -10.817846
# ...         ...          ...          ...
# 49995  MDAMB361    51.894910   -35.630085
# 49996  MDAMB361    52.289280   -35.708010
# 49997  MDAMB361    48.763325   -32.285027
# 49998  MDAMB361    43.193450    -5.901677
# 49999  MDAMB361    43.207320    -5.884901
#
# [50000 rows x 3 columns]

# %% [markdown]
# 2. Sampled fluxes:

# %%
dfFluxes_constraint1 = pd.read_csv(os.path.join(OUTDIR, 'sampledFluxes_rs_20210412081408_extr_0.csv.bz2'), compression = 'bz2', sep = '\t', index_col = 0)
dfFluxes_constraint1
# Out:
#                  EX_lac__L_e  EX_glc__D_e_r  EX_gluIN__L_e  EX_gluOUT__L_e  \
# MCF102A_13        344.086046      17.234421       0.049624        1.230487
# MCF102A_30        322.602009      16.606690       0.049414        4.283651
# MCF102A_68         87.013858      13.530424       0.049478        6.997511
# MCF102A_204        43.337935      14.299108       0.047719       27.978572
# MCF102A_380        29.681263      15.298179       0.049838        1.724315
# ...                      ...            ...            ...             ...
# MDAMB361_999485   120.323409      12.971716       0.030356        3.292692
# MDAMB361_999592   114.463944      12.340891       0.029937        2.228305
# MDAMB361_999676   117.721576      12.006618       0.031255       12.324544
# MDAMB361_999876   101.317555      12.528384       0.028719       13.230697
# MDAMB361_999925    95.282474      11.994030       0.028027       10.178494
#
#                  EX_gln__L_e_r  EX_asp__L_e  DM_asp__L_e    EX_co2_e  \
# MCF102A_13            2.395312     0.049573     1.995022  833.972972
# MCF102A_30            2.238027     0.049157     1.234493  812.974593
# MCF102A_68            2.099121     0.049098    66.279303  628.492664
# MCF102A_204           1.577081     0.043858    15.533633  554.087165
# MCF102A_380           1.862160     0.049894     6.559803  741.635438
# ...                        ...          ...          ...         ...
# MDAMB361_999485       3.319205     0.016580     0.006980  506.963397
# MDAMB361_999592       3.454492     0.017189     1.897476  464.358312
# MDAMB361_999676       3.584278     0.019384     1.394933  475.523973
# MDAMB361_999876       2.777952     0.017006     2.651511  513.012775
# MDAMB361_999925       2.822842     0.016465     2.385144  506.183302
#
#                  EX_pi_e_r    EX_nh4_e  ...     NDPK4     r0525     r0450  \
# MCF102A_13        0.035625  770.127436  ...  0.000501  0.011352  0.011352
# MCF102A_30        0.040462  749.954082  ...  0.000573  0.006220  0.006220
# MCF102A_68        0.210818  508.192639  ...  0.002976  0.054333  0.054333
# MCF102A_204       0.190664  441.018871  ...  0.002859  0.117557  0.117557
# MCF102A_380       0.119751  565.262837  ...  0.001822  0.167460  0.167460
# ...                    ...         ...  ...       ...       ...       ...
# MDAMB361_999485   0.284456  377.416235  ...  0.004312  0.211289  0.211289
# MDAMB361_999592   0.281473  337.463344  ...  0.004300  0.224087  0.224087
# MDAMB361_999676   0.239671  350.152075  ...  0.003634  0.230943  0.230943
# MDAMB361_999876   0.232424  376.768139  ...  0.003498  0.207158  0.207158
# MDAMB361_999925   0.215436  368.263515  ...  0.003280  0.246613  0.246613
#
#                    HACD1m  3SALAASPm  HMR_3951  ExSulfitem     TYRTA  \
# MCF102A_13       0.013357   0.252193  0.000608    0.252193  0.000012
# MCF102A_30       0.009943   0.270591  0.000343    0.270591  0.001168
# MCF102A_68       0.061480   0.130884  0.000116    0.130884  0.002187
# MCF102A_204      0.126545   0.107293  0.016814    0.107293  0.001388
# MCF102A_380      0.186391   0.268013  0.006861    0.268013  0.005063
# ...                   ...        ...       ...         ...       ...
# MDAMB361_999485  0.227323   0.020877  0.015505    0.020877  0.021373
# MDAMB361_999592  0.239023   0.011577  0.012165    0.011577  0.017376
# MDAMB361_999676  0.245226   0.013143  0.021495    0.013143  0.018539
# MDAMB361_999876  0.222337   0.004701  0.026627    0.004701  0.018279
# MDAMB361_999925  0.263797   0.013335  0.025199    0.013335  0.018913
#
#                    AM6SAD  2OXOADPTm
# MCF102A_13       0.002005   0.002005
# MCF102A_30       0.003723   0.003723
# MCF102A_68       0.007148   0.007148
# MCF102A_204      0.008988   0.008988
# MCF102A_380      0.018931   0.018931
# ...                   ...        ...
# MDAMB361_999485  0.016035   0.016035
# MDAMB361_999592  0.014936   0.014936
# MDAMB361_999676  0.014283   0.014283
# MDAMB361_999876  0.015179   0.015179
# MDAMB361_999925  0.017184   0.017184
#
# [50000 rows x 496 columns]

# %% [markdown]
# ## Constraint 2

# %%
# !python pipeline/PCAwtSNE.py 20210412174332

# %% [markdown]
# 1. t-SNE execution:

# %%
dftsne_constraint2 = pd.read_csv(os.path.join(OUTDIR, 'tsnewPca_rs_20210412174332_extr_0.csv'), sep = '\t', index_col = 0)
dftsne_constraint2
# Out:
#        cellLine  tsne-2d-one  tsne-2d-two
# 0       MCF102A    -0.171426     6.983644
# 1       MCF102A    -0.521310     7.033437
# 2       MCF102A     5.406816     0.622317
# 3       MCF102A     3.450798     2.558070
# 4       MCF102A    25.904078   -23.972696
# ...         ...          ...          ...
# 49995  MDAMB361   -60.675243    -9.864771
# 49996  MDAMB361   -60.756140   -10.604893
# 49997  MDAMB361   -60.680145   -12.323696
# 49998  MDAMB361   -59.937420   -11.311959
# 49999  MDAMB361   -62.342600   -17.283594
#
# [50000 rows x 3 columns]

# %% [markdown]
# 2. Sampled fluxes:

# %%
dfFluxes_constraint2 = pd.read_csv(os.path.join(OUTDIR, 'sampledFluxes_rs_20210412174332_extr_0.csv.bz2'), compression = 'bz2', sep = '\t', index_col = 0)
dfFluxes_constraint2
# Out:
#                  EX_lac__L_e  EX_glc__D_e_r  EX_gluIN__L_e  EX_gluOUT__L_e  \
# MCF102A_147       471.742487     278.475533       0.992279        3.702551
# MCF102A_151       499.283545     294.733808       0.865668        3.919592
# MCF102A_197       470.927575     277.993366       0.396554        3.695317
# MCF102A_232       481.830905     284.430024       0.147324        3.782166
# MCF102A_401       639.214759     377.338803       0.056207        5.024876
# ...                      ...            ...            ...             ...
# MDAMB361_999768    40.803926      48.767220       1.733820        4.933412
# MDAMB361_999773    38.460411      45.965042       2.687800        4.649960
# MDAMB361_999779    34.385465      41.096348       2.725136        4.157493
# MDAMB361_999807    35.258982      42.142179       2.227841        4.263654
# MDAMB361_999832    38.194832      45.646097       2.354670        4.618293
#
#                  EX_gln__L_e_r  EX_asp__L_e  DM_asp__L_e    EX_co2_e  \
# MCF102A_147          60.748072   150.500541   227.994069  978.473448
# MCF102A_151          64.297348   160.380320   251.332485  992.353974
# MCF102A_197          60.643858    73.527839   183.672515  860.641358
# MCF102A_232          62.049527    29.900373   225.632530  880.111228
# MCF102A_401          82.342635   122.334336   415.128624  934.674742
# ...                        ...          ...          ...         ...
# MDAMB361_999768     113.352474    19.597810   205.073052  840.345128
# MDAMB361_999773     106.843069    20.002013   263.249131  858.106343
# MDAMB361_999779      95.523738    15.193093   245.198691  858.075629
# MDAMB361_999807      97.950312    51.708987   289.199637  902.843327
# MDAMB361_999832     106.106239    35.629865   262.261140  906.216222
#
#                    EX_nh4_e   EX_o2_e_r  ...     NDPK4      r0525      r0450  \
# MCF102A_147      901.935006  784.730967  ...  0.242765   7.548999   7.548999
# MCF102A_151      916.796494  773.917097  ...  0.224779  13.614140  13.614140
# MCF102A_197      813.990997  701.095003  ...  0.273885  14.033302  14.033302
# MCF102A_232      885.095444  709.688809  ...  0.223526  27.544140  27.544140
# MCF102A_401      896.111534  755.847446  ...  0.311349  11.503155  11.503155
# ...                     ...         ...  ...       ...        ...        ...
# MDAMB361_999768  731.067833  792.003169  ...  0.115967   0.299829   0.299829
# MDAMB361_999773  749.077581  836.907054  ...  0.125239   0.126502   0.126502
# MDAMB361_999779  745.208517  846.494989  ...  0.113783   2.632327   2.632327
# MDAMB361_999807  772.510494  918.797222  ...  0.101907   6.009389   6.009389
# MDAMB361_999832  772.686463  916.785204  ...  0.121096   7.389505   7.389505
#
#                     HACD1m   3SALAASPm   HMR_3951  ExSulfitem     TYRTA  \
# MCF102A_147      13.113889  178.196552  87.201114  178.196552  1.358392
# MCF102A_151      24.376598  182.208055  88.559442  182.208055  1.349301
# MCF102A_197      17.681010  194.301256  34.202914  194.301256  2.101576
# MCF102A_232      29.345869  174.150245   2.686804  174.150245  1.429976
# MCF102A_401      15.413353  240.784063  10.148254  240.784063  0.300586
# ...                    ...         ...        ...         ...       ...
# MDAMB361_999768   4.642310  151.580580  61.686862  151.580580  0.758348
# MDAMB361_999773   6.164364  164.985673  61.711403  164.985673  0.621120
# MDAMB361_999779   8.899612  183.207109  59.551111  183.207109  0.681669
# MDAMB361_999807  13.187607  237.322321  51.073366  237.322321  0.085377
# MDAMB361_999832  19.245397  192.306170  98.239140  192.306170  0.165477
#
#                     AM6SAD  2OXOADPTm
# MCF102A_147       5.564890   5.564890
# MCF102A_151      10.762458  10.762458
# MCF102A_197       3.647707   3.647707
# MCF102A_232       1.801729   1.801729
# MCF102A_401       3.910198   3.910198
# ...                    ...        ...
# MDAMB361_999768   4.342481   4.342481
# MDAMB361_999773   6.037862   6.037862
# MDAMB361_999779   6.267285   6.267285
# MDAMB361_999807   7.178217   7.178217
# MDAMB361_999832  11.855892  11.855892
#
# [50000 rows x 496 columns]

# %% [markdown]
# ## Constraint 3

# %%
# !python pipeline/PCAwtSNE.py 20210423112500

# %% [markdown]
# 1. t-SNE execution:

# %%
dftsne_constraint3 = pd.read_csv(os.path.join(OUTDIR, 'tsnewPca_rs_20210423112500_extr_0.csv'), sep = '\t', index_col = 0)
dftsne_constraint3
# Out:
#        cellLine  tsne-2d-one  tsne-2d-two
# 0       MCF102A     6.696501    -7.587944
# 1       MCF102A    10.122231    -8.769357
# 2       MCF102A     8.943892    -8.820382
# 3       MCF102A     2.827076   -11.044170
# 4       MCF102A     2.644853    -4.870687
# ...         ...          ...          ...
# 49995  MDAMB361   -22.453653     7.580008
# 49996  MDAMB361   -27.967190     2.674379
# 49997  MDAMB361   -34.359478     7.088756
# 49998  MDAMB361   -33.632244     6.750492
# 49999  MDAMB361   -30.765636     6.148248
#
# [50000 rows x 3 columns]

# %% [markdown]
# 2. Sampled fluxes:

# %%
dfFluxes_constraint3 = pd.read_csv(os.path.join(OUTDIR, 'sampledFluxes_rs_20210423112500_extr_0.csv.bz2'), compression = 'bz2', sep = '\t', index_col = 0)
dfFluxes_constraint3
# Out:
#                  EX_lac__L_e  EX_glc__D_e_r  EX_gluIN__L_e  EX_gluOUT__L_e  \
# Unnamed: 0
# MCF102A_214       557.035443     222.626965     919.154867      946.788316
# MCF102A_229       548.801796     220.365599     909.511319      932.840845
# MCF102A_233       596.986407     222.958422     872.402875      895.290630
# MCF102A_254       650.027612     228.067915     884.621594      923.265879
# MCF102A_277       577.373212     200.579372     867.943712      901.822292
# ...                      ...            ...            ...             ...
# MDAMB361_999350    51.490407      48.217296     654.619211      684.967905
# MDAMB361_999553    55.508266      67.522411     674.030062      685.964148
# MDAMB361_999559    54.253743      64.948198     646.609039      662.055000
# MDAMB361_999637    56.123459      55.051502     663.977406      680.226507
# MDAMB361_999808    55.776208      79.344376     597.191236      642.310366
#
#                  EX_gln__L_e_r  EX_asp__L_e  DM_asp__L_e    EX_co2_e  \
# Unnamed: 0
# MCF102A_214          35.045901   973.810822   834.402247  549.848107
# MCF102A_229          16.909562   960.831443   768.544755  637.506030
# MCF102A_233          14.679221   926.062771   725.259851  606.555552
# MCF102A_254          22.242579   956.354075   674.186785  640.547315
# MCF102A_277          10.823203   905.455467   643.752674  611.433405
# ...                        ...          ...          ...         ...
# MDAMB361_999350      20.253295   530.960457   493.714342  494.647200
# MDAMB361_999553      12.340092   578.964298   529.033882  574.498630
# MDAMB361_999559      15.182714   561.306063   509.153602  573.825625
# MDAMB361_999637      11.886463   603.689080   558.043705  547.561477
# MDAMB361_999808      29.279464   562.995089   497.100686  576.027578
#
#                  EX_ump_e_r  EX_pi_e_r  ...     r0074  GLU5SAtmc    G5SADs  \
# Unnamed: 0                              ...
# MCF102A_214        0.339637   5.541963  ...  1.833903   1.833903  1.833903
# MCF102A_229        0.264910   5.297805  ...  1.581381   1.581381  1.581381
# MCF102A_233        0.318978   5.639535  ...  1.599555   1.599555  1.599555
# MCF102A_254        0.296419   5.812794  ...  1.755979   1.755979  1.755979
# MCF102A_277        0.316768   6.522362  ...  2.307844   2.307844  2.307844
# ...                     ...        ...  ...       ...        ...       ...
# MDAMB361_999350    0.260818   2.782434  ...  0.862065   0.862065  0.862065
# MDAMB361_999553    0.264390   2.921273  ...  0.646867   0.646867  0.646867
# MDAMB361_999559    0.266280   2.837511  ...  0.667832   0.667832  0.667832
# MDAMB361_999637    0.245039   2.642074  ...  0.755807   0.755807  0.755807
# MDAMB361_999808    0.229342   2.345985  ...  0.643473   0.643473  0.643473
#
#                     GHMT2r     ALATA_L      MTHFC     MTHFD2i    PTRCtex2  \
# Unnamed: 0
# MCF102A_214      12.144908  175.536269  -6.511444 -150.904384  -57.330403
# MCF102A_229      17.342767  293.532509 -10.090428 -130.404857  -60.897642
# MCF102A_233      42.379703  286.198782 -42.255781 -190.350491  -56.959384
# MCF102A_254      89.082879  413.681768 -82.232527 -240.640495 -143.466042
# MCF102A_277      66.760080  387.542255 -66.062705 -235.696371  -52.420136
# ...                    ...         ...        ...         ...         ...
# MDAMB361_999350 -30.675745  160.845122 -10.608809   37.680749   -8.182959
# MDAMB361_999553 -40.367698  162.702063  -4.947431   20.694314   -7.939371
# MDAMB361_999559 -38.615894  168.818016  -5.890941   29.257879  -24.014335
# MDAMB361_999637 -33.901396  155.257771  -4.554890    2.314114  -42.838758
# MDAMB361_999808 -19.441375  119.172724   5.069019    7.809173  -46.923601
#
#                        H2Ot     PHLACHt
# Unnamed: 0
# MCF102A_214      229.987168  677.011362
# MCF102A_229      238.898869  685.006058
# MCF102A_233      232.681996  697.229455
# MCF102A_254      227.321827  892.954092
# MCF102A_277      251.050146  728.983949
# ...                     ...         ...
# MDAMB361_999350  377.483798  158.587540
# MDAMB361_999553  404.730592  118.304189
# MDAMB361_999559  399.344630  152.287771
# MDAMB361_999637  391.392946  133.536560
# MDAMB361_999808  338.650773  170.478560
#
# [50000 rows x 496 columns]

# %% [markdown]
# ## Constraint 1+2+3

# %%
# !python pipeline/PCAwtSNE.py 20210406172233

# %% [markdown]
# 1. t-SNE execution:

# %%
dftsne_constraint123 = pd.read_csv(os.path.join(OUTDIR, 'tsnewPca_rs_20210406172233_extr_0.csv'), sep = '\t', index_col = 0)
dftsne_constraint123
# Out:
#        cellLine  tsne-2d-one  tsne-2d-two
# 0       MCF102A    24.774780   -47.068527
# 1       MCF102A    11.208630   -48.115917
# 2       MCF102A    22.841670   -54.284245
# 3       MCF102A     3.121974   -57.701230
# 4       MCF102A    -9.668979   -40.705250
# ...         ...          ...          ...
# 49995  MDAMB361   -57.377495   -13.456822
# 49996  MDAMB361   -55.594290   -16.572649
# 49997  MDAMB361   -53.248634   -21.500425
# 49998  MDAMB361   -56.330290   -16.950861
# 49999  MDAMB361   -57.496902   -23.419320
#
# [50000 rows x 3 columns]

# %% [markdown]
# 2. Sampled fluxes:

# %%
dfFluxes_constraint123 = pd.read_csv(os.path.join(OUTDIR, 'sampledFluxes_rs_20210406172233_extr_0.csv.bz2'), compression = 'bz2', sep = '\t', index_col = 0)
dfFluxes_constraint123
# Out:
#                  EX_lac__L_e  EX_glc__D_e_r  EX_gluIN__L_e  EX_gluOUT__L_e  \
# MCF102A_190         5.812242       3.428459       0.033170        0.042107
# MCF102A_355         4.968355       2.931951       0.024609        0.034731
# MCF102A_439         6.721770       3.964437       0.040175        0.048514
# MCF102A_451         6.706035       3.954989       0.043455        0.046779
# MCF102A_478         6.746945       3.979980       0.044588        0.045815
# ...                      ...            ...            ...             ...
# MDAMB361_999107     0.049144       0.082400       0.004207        0.007953
# MDAMB361_999171     0.044726       0.075422       0.003594        0.008216
# MDAMB361_999404     0.044067       0.069865       0.002415        0.007968
# MDAMB361_999554     0.059007       0.099300       0.006477        0.009890
# MDAMB361_999888     0.053597       0.080599       0.004717        0.009862
#
#                  EX_gln__L_e_r  EX_asp__L_e  DM_asp__L_e    EX_co2_e  \
# MCF102A_190           0.742924     0.047669     0.217395  167.209233
# MCF102A_355           0.657779     0.045608     0.257583  115.320036
# MCF102A_439           0.857003     0.049798     1.092762  130.086668
# MCF102A_451           0.863140     0.047865     0.785603  117.773466
# MCF102A_478           0.865158     0.046701     0.522181  144.455885
# ...                        ...          ...          ...         ...
# MDAMB361_999107       0.146760     0.004582     0.147547  123.066522
# MDAMB361_999171       0.135075     0.006617     0.102050  145.923138
# MDAMB361_999404       0.131958     0.007071     1.228219  162.995111
# MDAMB361_999554       0.173365     0.011818     0.389524  167.301842
# MDAMB361_999888       0.153577     0.005632     0.108654  173.782781
#
#                  EX_ump_e_r  EX_pi_e_r  ...     r0074  GLU5SAtmc    G5SADs  \
# MCF102A_190        0.000648   0.028391  ...  0.010686   0.010686  0.010686
# MCF102A_355        0.001189   0.028853  ...  0.008909   0.008909  0.008909
# MCF102A_439        0.001875   0.029180  ...  0.012036   0.012036  0.012036
# MCF102A_451        0.002026   0.026000  ...  0.010851   0.010851  0.010851
# MCF102A_478        0.001756   0.024023  ...  0.009670   0.009670  0.009670
# ...                     ...        ...  ...       ...        ...       ...
# MDAMB361_999107    0.001986   0.026798  ...  0.006000   0.006000  0.006000
# MDAMB361_999171    0.001846   0.026888  ...  0.005077   0.005077  0.005077
# MDAMB361_999404    0.001620   0.026732  ...  0.004824   0.004824  0.004824
# MDAMB361_999554    0.001696   0.022298  ...  0.004362   0.004362  0.004362
# MDAMB361_999888    0.001765   0.023051  ...  0.006268   0.006268  0.006268
#
#                     GHMT2r   ALATA_L      MTHFC    MTHFD2i  PTRCtex2  \
# MCF102A_190     -20.718619  6.627197  -0.545392 -22.934694  0.018717
# MCF102A_355     -13.450910  0.943877  -3.423623 -36.339519  0.011644
# MCF102A_439     -18.586402  0.569263  -4.359320 -40.215981  0.037996
# MCF102A_451     -14.933904  0.703243  -6.057530 -34.692505  0.027668
# MCF102A_478     -16.697182  0.162887  -4.780065  -7.606046  0.016786
# ...                    ...       ...        ...        ...       ...
# MDAMB361_999107  -0.006402  0.926189 -11.212929 -46.454284  0.027689
# MDAMB361_999171  -0.207392  0.802968 -11.583263 -44.273600  0.024620
# MDAMB361_999404  -0.316993  2.399368 -11.646834 -51.838198  0.022612
# MDAMB361_999554  -0.212068  2.299181 -11.562626 -70.777830  0.026551
# MDAMB361_999888  -0.595065  0.374450 -11.316603 -72.587253  0.026623
#
#                        H2Ot     PHLACHt
# MCF102A_190      166.107191  -37.839369
# MCF102A_355       84.438212    9.803578
# MCF102A_439      103.332253  -10.042978
# MCF102A_451       61.986240    8.984514
# MCF102A_478      136.424819  -35.569428
# ...                     ...         ...
# MDAMB361_999107  139.875193  -63.634921
# MDAMB361_999171  192.350720  -94.769458
# MDAMB361_999404  251.550274 -129.521388
# MDAMB361_999554  236.211142 -125.190229
# MDAMB361_999888  246.552992 -126.252277
#
# [50000 rows x 496 columns]

# %% [markdown]
# After t-SNE execution, the resulting output files are plotted as follows.
#
# To run the script from the Jupyter notebook:
# ```python
# !python pipeline/plotTSNE.py tStampRS
# ```
#
# In alternative, to run the script from the terminal:
# ```python
# python pipeline/plotTSNE.py tStampRS
# ```
# Parameters:
# - *tStampRS* is the time stamp of the random sampling output file. For constraint 1 the time stamp is *20210412081408*, for constraint 2 is *20210412174332*, for constraint 3 is *20210423112500*, and for constraint 1+2+3 it is *20210406172233*.
#
# ## Constraint 1

# %%
# !python pipeline/plotTSNE.py 20210412081408

# %%
im = img.imread(os.path.join(FIGUREDIR, 'tsnewPca_rs_20210412081408_extr_0_tags.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %%
# !python pipeline/plotTSNE.py 20210412174332

# %%
im = img.imread(os.path.join(FIGUREDIR, 'tsnewPca_rs_20210412174332_extr_0_tags.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %%
# !python pipeline/plotTSNE.py 20210423112500

# %%
im = img.imread(os.path.join(FIGUREDIR, 'tsnewPca_rs_20210423112500_extr_0_tags.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %%
# !python pipeline/plotTSNE.py 20210406172233

# %%
im = img.imread(os.path.join(FIGUREDIR, 'tsnewPca_rs_20210406172233_extr_0_tags.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# # Figure 3B
# To run the script from the Jupyter notebook:
# ```python
# !python pipeline/computeGrowthYield.py tStampRS whichAnalysis
# ```
#
# In alternative, to run the script from the terminal:
# ```python
# python pipeline/computeGrowthYield.py tStampRS whichAnalysis
# ```
#
# Parameters:
# - *tStampRS* is the time stamp of the random sampling output file. For constraint 1 the time stamp is *20210412081408*, for constraint 2 is *20210412174332*, for constraint 3 is *20210423112500*, and for constraint 1+2+3 it is *20210406172233*.
# - *whichAnalysis* may be equal to *save* for processing the random sampling output file in order to obtain a file called 'yieldOnGlc_rs_' + tStampRS where the wet and the computational growth yield are computed for each cell line, or equal to *plot* for plotting a correlation plot between the computer wet and the computational growth yields.
#
# Because of the high dimension of the random sampling output files, this notebook only shows the *plot* phase.
#
# ## Constraint 1

# %%
# !python pipeline/computeGrowthYield.py 20210412081408 plot

# %%
im = img.imread(os.path.join(FIGUREDIR, 'yieldOnGlc_rs_20210412081408.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# ## Constraint 2

# %%
# !python pipeline/computeGrowthYield.py 20210412174332 plot

# %%
im = img.imread(os.path.join(FIGUREDIR, 'yieldOnGlc_rs_20210412174332.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# ## Constraint 3

# %%
# !python pipeline/computeGrowthYield.py 20210423112500 plot

# %%
im = img.imread(os.path.join(FIGUREDIR, 'yieldOnGlc_rs_20210423112500.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# ## Constraint 1+2+3

# %%
# !python pipeline/computeGrowthYield.py 20210406172233 plot

# %%
im = img.imread(os.path.join(FIGUREDIR, 'yieldOnGlc_rs_20210406172233.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# # Figure 5B - 5C
#
#
# To run the script from the Jupyter notebook:
# ```python
# !python pipeline/discriminativeFluxesScore.py tStampRS
# ```
#
# In alternative, to run the script from the terminal:
# ```python
# python pipeline/discriminativeFluxesScore.py tStampRS
# ```
#
# Parameters:
# - *tStampRS* is the time stamp of the random sampling output file. For constraint 1+2+3 the time stamp is *20210406172233*.

# %%
# !python pipeline/discriminativeFluxesScore.py 20210406172233

# %% [markdown]
# Because of the high dimension of the random sampling input files, this notebook don't show the execution of this phase, which is commented in the previous cell to be easily executed by the user, but only the resulting output:

# %%
dfDiscriminativeFluxesScore_constraint123 = pd.read_csv(os.path.join(OUTDIR, 'rs_20210406172233_fluxScores.csv'), sep = '\t', index_col = 0)
dfDiscriminativeFluxesScore_constraint123
# Out:
#                 MCF102A_score  SKBR3_score  MCF7_score  MDAMB231_score  \
# EX_gluOUT__L_e       0.796266     0.732168    0.740292        0.817245
# r2534_r              0.946093     0.862430    0.584588        0.390981
# EX_thr__L_e_r        0.946093     0.862430    0.584588        0.390981
# ExCystineGlu         0.549190     0.728027    0.783561        0.903110
# GluForTx             0.994639     0.771146    0.810451        0.183747
# ...                       ...          ...         ...             ...
# ORNt4m               0.000000     0.000000    0.000000        0.000000
# OCBTm                0.000000     0.000000    0.000000        0.000000
# CBPSam               0.000000     0.000000    0.000000        0.000000
# ILEtmi               0.000000     0.000000    0.000000        0.000000
# GTHS                 0.000000     0.000000    0.000000        0.000000
#
#                 MDAMB361_score  totalScore
# EX_gluOUT__L_e        0.988916    4.074888
# r2534_r               0.840491    3.624583
# EX_thr__L_e_r         0.840491    3.624583
# ExCystineGlu          0.596751    3.560638
# GluForTx              0.711225    3.471208
# ...                        ...         ...
# ORNt4m                0.000000    0.000000
# OCBTm                 0.000000    0.000000
# CBPSam                0.000000    0.000000
# ILEtmi                0.000000    0.000000
# GTHS                  0.000000    0.000000
#
# [496 rows x 6 columns]

# %% [markdown]
# **Then:**
#
# To run the script from the Jupyter notebook:
# ```python
# !python pipeline/tSNEandFluxDistributions.py tStampRS
# ```
#
# In alternative, to run the script from the terminal:
# ```python
# python pipeline/tSNEandFluxDistributions.py tStampRS
# ```
#
# Parameters:
# - *tStampRS* is the time stamp of the random sampling output file. For constraint 1+2+3 the time stamp is *20210406172233*.

# %%
im = img.imread(os.path.join(FIGUREDIR, 'sampledFluxes_rs_20210406172233_extr_0_ScatAndHistACONT.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %%
im = img.imread(os.path.join(FIGUREDIR, 'sampledFluxes_rs_20210406172233_extr_0_ScatAndHistOCOAT1m.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# # Figure 6
#
# To run the script from the Jupyter notebook:
# ```python
# !python pipeline/exAminoAcid2Biomass.py tStampRS
# ```
#
# In alternative, to run the script from the terminal:
# ```python
# python pipeline/exAminoAcid2Biomass.py tStampRS
# ```
#
# Parameters:
# - *tStampRS* is the time stamp of the random sampling output file. For constraint 1+2+3 the time stamp is *20210406172233*.

# %%
# !python pipeline/exAminoAcid2Biomass.py 20210406172233

# %% [markdown]
# Because of the high dimension of the random sampling input files, this notebook don't show the execution of this phase, which is commented in the previous cell to be easily executed by the user, but only the resulting outputs:

# %%
im = img.imread(os.path.join(FIGUREDIR, 'rs_20210406172233_BioMvsEXile__L.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %%
im = img.imread(os.path.join(FIGUREDIR, 'rs_20210406172233_BioMvsEXval__L.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %%
im = img.imread(os.path.join(FIGUREDIR, 'rs_20210406172233_BioMvsEXleu__L.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %%
im = img.imread(os.path.join(FIGUREDIR, 'rs_20210406172233_BioMvsEXtyr__L.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)
