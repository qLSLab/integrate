# %% [markdown]
# # Data analysis
#
# In this notebook, code for reproducing all the Figure of [INTEGRATE paper]() is presented.

# %%
import pandas as pd
import matplotlib.image as img
import matplotlib.pyplot as plt
pipelineDir = './pipeline'
import sys
import os
sys.path.append(pipelineDir)
import genericLib as gL

workingDirs = gL.setWorkingDirs()
OUTDIR = workingDirs[2]
FIGUREDIR = workingDirs[4]

# %% [markdown]
# # Figure 2
#
# To run the script from the Jupyter notebook:
# ```python
# !python pipeline/dataAnalysis.py
# ```
#
# In alternative, to run the script from the terminal:
# ```python
# python pipeline/dataAnalysis.py
# ```

# %%
# !python pipeline/dataAnalysis.py
# Out:
# (90, 100)
# C:\Users\bruno\anaconda3\lib\site-packages\anndata\_core\anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'clusters' as categorical

# %% [markdown]
# The produced outputs are:
# 1. Cell Vs Protein figure

# %%
im = img.imread(os.path.join(FIGUREDIR, 'ProteinsVsCells.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# 2. Cell Vs Time figure

# %%
im = img.imread(os.path.join(FIGUREDIR, 'CellsVsTime.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# 3. Proteins Vs Time figure

# %%
im = img.imread(os.path.join(FIGUREDIR, 'ProteinsVsTime.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# 4. t-SNE of metabolomic data

# %%
im = img.imread(os.path.join(FIGUREDIR, 'tsne.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# 5. Dotplot

# %%
im = img.imread(os.path.join(FIGUREDIR, 'dotplot.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# # Figure 3A-3D

# %% [markdown]
# Firstly t-SNE is executed on a subset of the sampled solutions from the Step 6.
# To run the script from the Jupyter notebook:
# ```python
# !python pipeline/PCAwtSNE.py tStampRS
# ```
#
# In alternative, to run the script from the terminal:
# ```python
# python pipeline/PCAwtSNE.py tStampRS
# ```
# Parameters:
# - *tStampRS* is the time stamp of the random sampling output file. For constraint 1 the time stamp is *20210412081408*, for constraint 2 is *20210412174332*, for constraint 3 is *20210423112500*, and for constraint 1+2+3 it is *20210406172233*.
#
# Because of the high dimension of the random sampling input files, this notebook don't show the execution of this phase, which is commented in the following cells to be easily executed by the user, but only the resulting output:

# %% [markdown]
# ## Constraint 1

# %%
# !python pipeline/PCAwtSNE.py 20210412081408

# %% [markdown]
# t-SNE execution:

# %%
dftsne_constraint1 = pd.read_csv(os.path.join(OUTDIR, 'tsnewPca_randomSampling_M_20211203.csv'), sep = '\t', index_col = 0)
dftsne_constraint1
# Out:
#        cellLine  tsne-2d-one  tsne-2d-two
# 0       MCF102A    40.080540    -6.078287
# 1       MCF102A    40.082390    -6.073716
# 2       MCF102A    40.080560    -6.074290
# 3       MCF102A    40.078537    -6.070314
# 4       MCF102A    40.078255    -6.066834
# ...         ...          ...          ...
# 49995  MDAMB361    12.611897   -11.493196
# 49996  MDAMB361    12.608893   -11.486942
# 49997  MDAMB361    12.614447   -11.482278
# 49998  MDAMB361    12.602820   -11.477445
# 49999  MDAMB361    12.620877   -11.473863
#
# [50000 rows x 3 columns]

# %% [markdown]
# ## Constraint 1+2

# %%
# !python pipeline/PCAwtSNE.py 20210412174332

# %% [markdown]
# t-SNE execution:

# %%
dftsne_constraint2 = pd.read_csv(os.path.join(OUTDIR, 'tsnewPca_randomSampling_MY_20211203.csv'), sep = '\t', index_col = 0)
dftsne_constraint2
# Out:
#        cellLine  tsne-2d-one  tsne-2d-two
# 0       MCF102A   -27.590612     7.545937
# 1       MCF102A   -27.587946     7.546614
# 2       MCF102A   -27.587986     7.545779
# 3       MCF102A   -27.592169     7.537263
# 4       MCF102A   -27.592669     7.537821
# ...         ...          ...          ...
# 49995  MDAMB361   -40.458313    -0.612785
# 49996  MDAMB361   -40.501415    -0.475598
# 49997  MDAMB361   -40.640755    -0.333985
# 49998  MDAMB361   -40.657190    -0.253559
# 49999  MDAMB361   -40.696480    -0.151144
#
# [50000 rows x 3 columns]

# %% [markdown]
# ## Constraint 3

# %%
# !python pipeline/PCAwtSNE.py 20210423112500

# %% [markdown]
# t-SNE execution:

# %%
dftsne_constraint3 = pd.read_csv(os.path.join(OUTDIR, 'tsnewPca_randomSampling_R_20211203.csv'), sep = '\t', index_col = 0)
dftsne_constraint3
# Out:
#        cellLine  tsne-2d-one  tsne-2d-two
# 0       MCF102A   -10.163519     6.769546
# 1       MCF102A   -10.164467     6.768350
# 2       MCF102A   -10.163246     6.769268
# 3       MCF102A   -10.163011     6.769562
# 4       MCF102A   -10.162637     6.770550
# ...         ...          ...          ...
# 49995  MDAMB361   -20.151281     2.768580
# 49996  MDAMB361   -20.147913     2.761447
# 49997  MDAMB361   -20.174997     2.460037
# 49998  MDAMB361   -20.177992     2.528261
# 49999  MDAMB361   -20.208110     2.527703
#
# [50000 rows x 3 columns]

# %% [markdown]
# ## Constraint 1+2+3

# %%
# !python pipeline/PCAwtSNE.py 20210406172233

# %% [markdown]
# t-SNE execution:

# %%
dftsne_constraint123 = pd.read_csv(os.path.join(OUTDIR, 'tsnewPca_randomSampling_MRY_20211203.csv'), sep = '\t', index_col = 0)
dftsne_constraint123
# Out:
#        cellLine  tsne-2d-one  tsne-2d-two
# 0       MCF102A     9.586196    37.368480
# 1       MCF102A     9.587518    37.355198
# 2       MCF102A     9.493565    37.287070
# 3       MCF102A     9.474820    37.277780
# 4       MCF102A     9.490798    37.285400
# ...         ...          ...          ...
# 49995  MDAMB361   -35.277680    -6.317208
# 49996  MDAMB361   -34.291940    -6.341990
# 49997  MDAMB361   -35.795776    -5.917844
# 49998  MDAMB361   -36.014885    -5.803478
# 49999  MDAMB361   -36.337673    -5.936718
#
# [50000 rows x 3 columns]

# %% [markdown]
# After t-SNE execution, the resulting output files are plotted as follows.
#
# To run the script from the Jupyter notebook:
# ```python
# !python pipeline/plotTSNE.py tStampRS
# ```
#
# In alternative, to run the script from the terminal:
# ```python
# python pipeline/plotTSNE.py tStampRS
# ```
# Parameters:
# - *tStampRS* is the time stamp of the random sampling output file. For constraint 1 the time stamp is *20210412081408*, for constraint 2 is *20210412174332*, for constraint 3 is *20210423112500*, and for constraint 1+2+3 it is *20210406172233*.

# %% [markdown]
# ## Constraint 1

# %%
#!python pipeline/plotTSNE.py 20210412081408

# %%
im = img.imread(os.path.join(FIGUREDIR, 'tsnewPca_randomSampling_M_20211203_tags.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# ## Constraint 1+2

# %%
#!python pipeline/plotTSNE.py 20210412174332

# %%
im = img.imread(os.path.join(FIGUREDIR, 'tsnewPca_randomSampling_MY_20211203_tags.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# ## Constraint 3

# %%
#!python pipeline/plotTSNE.py 20210423112500

# %%
im = img.imread(os.path.join(FIGUREDIR, 'tsnewPca_randomSampling_R_20211203_tags.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# ## Constraint 1+2+3

# %%
#!python pipeline/plotTSNE.py 20210406172233

# %%
im = img.imread(os.path.join(FIGUREDIR, 'tsnewPca_randomSampling_MRY_20211203_tags.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# # Figure 3E
# To run the script from the Jupyter notebook:
# ```python
# !python pipeline/computeGrowthYield.py tStampRS whichAnalysis
# ```
#
# In alternative, to run the script from the terminal:
# ```python
# python pipeline/computeGrowthYield.py tStampRS whichAnalysis
# ```
#
# Parameters:
# - *tStampRS* is the time stamp of the random sampling output file. For constraint 1 the time stamp is *20210412081408*, for constraint 2 is *20210412174332*, for constraint 3 is *20210423112500*, and for constraint 1+2+3 it is *20210406172233*.
# - *whichAnalysis* may be equal to *save* for processing the random sampling output file in order to obtain a file called 'yieldOnGlc_rs_' + tStampRS where the wet and the computational growth yield are computed for each cell line, or equal to *plot* for plotting a correlation plot between the computer wet and the computational growth yields.
#
# Because of the high dimension of the random sampling output files, this notebook only shows the *plot* phase.

# %% [markdown]
# ## Constraint 1

# %%
#!python pipeline/computeGrowthYield.py 20210412081408 plot

# %%
im = img.imread(os.path.join(FIGUREDIR, 'yieldENGRO_wetVsSilico_Glc_MEDIANSpearman_M_20211203.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# ## Constraint 1+2

# %%
#!python pipeline/computeGrowthYield.py 20210412174332 plot

# %%
im = img.imread(os.path.join(FIGUREDIR, 'yieldENGRO_wetVsSilico_Glc_MEDIANSpearman_MY_20211203.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# ## Constraint 3

# %%
#!python pipeline/computeGrowthYield.py 20210423112500 plot

# %%
im = img.imread(os.path.join(FIGUREDIR, 'yieldENGRO_wetVsSilico_Glc_MEDIANSpearman_R_20211203.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# ## Constraint 1+2+3

# %%
#!python pipeline/computeGrowthYield.py 20210406172233 plot

# %%
im = img.imread(os.path.join(FIGUREDIR, 'yieldENGRO_wetVsSilico_Glc_MEDIANSpearman_MRY_20211203.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)

# %% [markdown]
# # Figure 5B - 5C

# %% [markdown]
# To run the script from the Jupyter notebook:
# ```python
# !python pipeline/tSNEandFluxDistributions.py tStampRS
# ```
#
# In alternative, to run the script from the terminal:
# ```python
# python pipeline/tSNEandFluxDistributions.py tStampRS
# ```
#
# Parameters:
# - *tStampRS* is the time stamp of the random sampling output file. For constraint 1+2+3 the time stamp is *20210406172233*.

# %%
im = img.imread(os.path.join(FIGUREDIR, 'sampledFluxes_rs_20210406172233_extr_0_ScatAndHistACONT.png'))
  
# show image
plt.figure(figsize=(20,10))
plt.imshow(im)
